# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ee-ortiz/ISIS-4825_202510_IMAGENES_Y_VISION/blob/main/Laboratorio_10/MISIS4825_Laboratorio10_Taller.ipynb)

# %% [markdown]
# ![image](https://drive.google.com/u/0/uc?id=15DUc09hFGqR8qcpYiN1OajRNaASmiL6d&export=download)

# %% [markdown]
# # Laboratorio 10 – Taller: Segmentación de Imágenes con U-Net
#
# ## Introducción
#
# Este taller abordará el problema de la **segmentación semántica**, que consiste en asignar a cada píxel de una imagen una etiqueta de clase. A diferencia de la detección de objetos, la segmentación ofrece un mapa preciso de las regiones de interés, con aplicaciones en:
#
# - **Medicina**: delimitación de tumores o estructuras anatómicas en imágenes de resonancia magnética o tomografía computarizada.
# - **Agricultura de precisión**: identificación y cuantificación de cultivos y malezas en imágenes aéreas.
# - **Automoción**: segmentación de calzadas, vehículos y peatones en sistemas de conducción autónoma.
#
# La arquitectura **U-Net**, propuesta originalmente para segmentación biomédica en 2015, se caracteriza por su forma de "U": un **encoder** que extrae características de alto nivel y un **decoder** que recupera la resolución espacial, unidos mediante conexiones de salto (*skip connections*) para conservar detalle fino y contexto global.
#
# ## Objetivos
#
# 1. **Construir la arquitectura U-Net** desde cero:
#    - Definición del *encoder* (bloques convolucionales y operaciones de *pooling*).
#    - Definición del *decoder* (upsampling y concatenaciones con conexiones de salto).
# 2. **Configurar el entrenamiento**: función de pérdida adecuada, optimizador y métricas.
# 3. **Entrenar el modelo** y analizar las curvas de pérdida y métricas para identificar sobreajuste o subajuste.
# 4. **Evaluar el rendimiento** de forma cuantitativa (IoU medio, precisión de píxel) y cualitativa (visualización de máscaras superpuestas).
#
#
# **Datos**
# Se empleará el dataset **Oxford-IIIT Pet**, que incluye imágenes JPG de mascotas y máscaras PNG anotadas para 37 razas distintas.
#
# - Descarga: https://www.robots.ox.ac.uk/~vgg/data/pets/
# - Formato: imágenes + máscaras con valores de clase por píxel

# %% [markdown]
# ## 1. Descarga, preparación y preprocesamiento del dataset
#
# En esta sección se carga **Oxford-IIIT Pet**, se redimensionan imágenes y máscaras, se normalizan los valores de píxel, se recodifican las máscaras de \{1,2,3\} a \{0,1,2\}, se expande el canal de las máscaras, y se crean los splits de entrenamiento, validación de prueba (70/15/15).

# %%
import tensorflow as tf
import logging
import tensorflow_datasets as tfds
tfds.disable_progress_bar()
logging.getLogger("tensorflow_datasets").setLevel(logging.ERROR)
from tensorflow.keras.preprocessing.image import smart_resize
import numpy as np

# %%
# 1. Parámetros
BATCH_SIZE = 16
TARGET_SIZE = (160, 160)
N_CLASSES = 3

# 2. Generador con redimensionado, normalización y recodificación de máscaras
def pet_generator(split):
    """
    Lee Oxford-IIIT Pet v4 desde TFDS y devuelve lotes (X, Y) con:
      - X: imágenes float32 en [0,1], forma (batch, H, W, 3)
      - Y: máscaras uint8 en {0,1,2}, forma (batch, H, W, 1)
    """
    ds = tfds.load("oxford_iiit_pet:4.*.*", split=split, as_supervised=False)
    ds = ds.repeat().shuffle(1024)
    it = iter(tfds.as_numpy(ds))
    while True:
        batch_X, batch_Y = [], []
        for _ in range(BATCH_SIZE):
            sample = next(it)
            # Imagen: resize + normalización
            img = smart_resize(sample["image"], TARGET_SIZE).astype(np.float32) / 255.0
            # Máscara: resize + recodificar + expandir canal
            msk = smart_resize(sample["segmentation_mask"], TARGET_SIZE)
            mask = (msk[..., 0].astype(np.int32) - 1)[..., np.newaxis].astype(np.uint8)
            batch_X.append(img)
            batch_Y.append(mask)
        yield np.stack(batch_X), np.stack(batch_Y)

# 3. Splits 70% / 15% / 15%
TRAIN_SPLIT = "train+test[:70%]"
VAL_SPLIT   = "train+test[70%:85%]"
TEST_SPLIT  = "train+test[85%:]"

# 4. Crear generadores
train_gen = pet_generator(TRAIN_SPLIT)
val_gen   = pet_generator(VAL_SPLIT)
test_gen  = pet_generator(TEST_SPLIT)

# 5. Cálculo de pasos por época y conteo de muestras
_, info = tfds.load("oxford_iiit_pet:4.*.*", with_info=True)
n_total = info.splits["train"].num_examples + info.splits["test"].num_examples

steps_train = int((n_total * 0.70) // BATCH_SIZE)
steps_val   = int((n_total * 0.15) // BATCH_SIZE)
steps_test  = int((n_total * 0.15) // BATCH_SIZE)

n_train = int(0.70 * n_total)
n_val   = int(0.15 * n_total)
n_test  = n_total - n_train - n_val

print(f"Total de muestras: {n_total}")
print(f"  Train (70%): {n_train}")
print(f"  Val   (15%): {n_val}")
print(f"  Test  (15%): {n_test}")
print(f"Pasos por época -> train: {steps_train}, val: {steps_val}, test: {steps_test}")
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/oxford_iiit_pet/4.0.0 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/oxford_iiit_pet/4.0.0...
# Dataset oxford_iiit_pet downloaded and prepared to /root/tensorflow_datasets/oxford_iiit_pet/4.0.0. Subsequent calls will reuse this data.
# Total de muestras: 7349
#   Train (70%): 5144
#   Val   (15%): 1102
#   Test  (15%): 1103
# Pasos por época -> train: 321, val: 68, test: 68

# %% [markdown]
# ## 2. Exploración de Datos
#
# Antes de entrenar el modelo, debemos revisar las imágenes para verificar su calidad y la precisión de las máscaras.
#
# Las máscaras contienen las siguientes etiquetas:
#
# - **0**: Fondo.
# - **1**: Mascota.
# - **2**: Borde. Esta etiqueta ayuda a la red a delimitar contornos con mayor precisión.

# %%
import matplotlib.pyplot as plt

# Obtener un lote de entrenamiento
x_batch, y_batch = next(train_gen)

# Seleccionar tres ejemplos dentro del lote
indices = [0, 4, 8]

plt.figure(figsize=(10, 8))
for i, idx in enumerate(indices):
    # Imagen original
    ax = plt.subplot(3, 2, 2*i + 1)
    ax.imshow((x_batch[idx] * 255).astype("uint8"))
    ax.set_title(f"Imagen {idx}")
    ax.axis("off")

    # Máscara correspondiente
    ax = plt.subplot(3, 2, 2*i + 2)
    ax.imshow(y_batch[idx, ..., 0], cmap="gray")
    ax.set_title("Máscara (0=fondo,1=mascota,2=borde)")
    ax.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3 Arquitectura U-Net
#
# La U-Net, presentada por Ronneberger et al. en 2015 en  **"U-Net: Convolutional Networks for Biomedical Image Segmentation"** ([ver paper](https://arxiv.org/abs/1505.04597)), consiste en dos caminos:
#
# * **Encoder (contracción)**: captura contexto global mediante convoluciones y max-pooling.
# * **Decoder (expansión)**: recupera resolución espacial y refina los contornos usando upsampling y concatenaciones con las capas del encoder (*skip connections*).
#
# > A continuación se se presenta una ilustración de la arquitectura U-Net:
# >
# > ![U-Net Architecture](https://miro.medium.com/v2/resize:fit:1800/1*Rmo71TyPxvLLM4FnlH5MDg.jpeg)

# %%
from tensorflow.keras import layers, Model, Input

# Realiza dos convoluciones consecutivas con activación ReLU
def doble_conv(x, filters):
    x = layers.Conv2D(filters, 3, padding='same', activation='relu')(x)  # Primera convolución
    x = layers.Conv2D(filters, 3, padding='same', activation='relu')(x)  # Segunda convolución
    return x

# Bloque de descenso (encoder): reduce la resolución y extrae características
def encoder_block(x, filters):
    f = doble_conv(x, filters)         # Convoluciones
    p = layers.MaxPool2D(2)(f)         # Reducción de resolución
    p = layers.Dropout(0.2)(p)         # Regularización
    return f, p                        # Retorna características y salida reducida

# Bloque de ascenso (decoder): aumenta la resolución y combina características
def up_block(x, skip, filters):
    x = layers.Conv2DTranspose(filters, 3, strides=2, padding='same')(x)  # Upsampling
    x = layers.concatenate([x, skip])                                    # Conexión de salto
    x = layers.Dropout(0.2)(x)                                           # Regularización
    x = doble_conv(x, filters)                                           # Convoluciones
    return x

# Construcción de la U-Net
def build_unet(input_shape=(160, 160, 3), n_classes=3):
    inputs = Input(input_shape)  # Entrada del modelo

    # Encoder (menor profundidad y filtros reducidos)
    f1, c1 = encoder_block(inputs,  16)
    f2, c2 = encoder_block(c1,      32)
    f3, c3 = encoder_block(c2,      64)

    # Bottleneck
    b = doble_conv(c3, 128)

    # Decoder
    u1 = up_block(b,  f3, 64)
    u2 = up_block(u1, f2, 32)
    u3 = up_block(u2, f1, 16)

    # Capa de salida: mapa de segmentación con convolución 1×1
    outputs = layers.Conv2D(n_classes, 1, padding='same', activation='softmax')(u3)
    return Model(inputs, outputs)

# Crear y resumir el modelo
model = build_unet()
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 160, 160,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 160, 160,  │        448 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 160, 160,  │      2,320 │ conv2d[0][0]      │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 80, 80,    │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 80, 80,    │          0 │ max_pooling2d[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 80, 80,    │      4,640 │ dropout[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 80, 80,    │      9,248 │ conv2d_2[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 40, 40,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 40, 40,    │          0 │ max_pooling2d_1[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 40, 40,    │     18,496 │ dropout_1[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 40, 40,    │     36,928 │ conv2d_4[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 20, 20,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 20, 20,    │          0 │ max_pooling2d_2[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 20, 20,    │     73,856 │ dropout_2[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 20, 20,    │    147,584 │ conv2d_6[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 40, 40,    │     73,792 │ conv2d_7[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 40, 40,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 40, 40,    │          0 │ concatenate[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 40, 40,    │     73,792 │ dropout_3[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 40, 40,    │     36,928 │ conv2d_8[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 80, 80,    │     18,464 │ conv2d_9[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 80, 80,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 80, 80,    │          0 │ concatenate_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 80, 80,    │     18,464 │ dropout_4[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 80, 80,    │      9,248 │ conv2d_10[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 160, 160,  │      4,624 │ conv2d_11[0][0]   │
# │ (Conv2DTranspose)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 160, 160,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 32)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 160, 160,  │          0 │ concatenate_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 160, 160,  │      4,624 │ dropout_5[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 160, 160,  │      2,320 │ conv2d_12[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 160, 160,  │         51 │ conv2d_13[0][0]   │
# │                     │ 3)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 535,827 (2.04 MB)
#  Trainable params: 535,827 (2.04 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 4. Entrenamiento del modelo
#
# En esta sección se compila la U-Net incluyendo, además de la exactitud, la métrica de **IoU medio**. Para la comparación con Dice, definimos una función auxiliar que se usará en la evaluación posterior.

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# 1. Métrica MeanIoU
class MeanIoUArgmax(tf.keras.metrics.MeanIoU):
    def update_state(self, y_true, y_pred, sample_weight=None):
        # Convertir probabilidades a etiquetas
        y_pred_labels = tf.argmax(y_pred, axis=-1)
        # Quitar el canal extra de y_true
        y_true = tf.squeeze(y_true, axis=-1)
        return super().update_state(y_true, y_pred_labels, sample_weight)

# 2. Métrica Dice
def dice_coef(y_true, y_pred, smooth=1e-6):
    y_true_ohe = tf.one_hot(tf.squeeze(y_true, -1), depth=N_CLASSES)
    y_pred_lbl = tf.one_hot(tf.argmax(y_pred, -1), depth=N_CLASSES)
    y_true_f = tf.reshape(y_true_ohe, [-1, N_CLASSES])
    y_pred_f = tf.reshape(y_pred_lbl, [-1, N_CLASSES])
    inter = tf.reduce_sum(y_true_f * y_pred_f, axis=0)
    union = tf.reduce_sum(y_true_f + y_pred_f, axis=0)
    return tf.reduce_mean((2.*inter + smooth) / (union + smooth))

# 3. Callbacks para guardar el mejor modelo y detenerse temprano
callbacks = [
    ModelCheckpoint(
        'best_unet_model.keras',
        monitor='val_loss',
        save_best_only=True
    ),
    EarlyStopping(
        monitor='val_loss',
        patience=5,
        restore_best_weights=True
    )
]

# 4. Compilación
model.compile(
    optimizer='rmsprop',
    loss='sparse_categorical_crossentropy',
    metrics=[
        'accuracy',
        MeanIoUArgmax(num_classes=N_CLASSES, name='mean_iou'),
        dice_coef
    ]
)

# 5. Entrenamiento
history = model.fit(
    train_gen,
    steps_per_epoch=steps_train,
    validation_data=val_gen,
    validation_steps=steps_val,
    epochs=20,
    callbacks=callbacks
)
# Out:
# Epoch 1/20
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 79s 196ms/step - accuracy: 0.5149 - dice_coef: 0.2793 - loss: 0.9577 - mean_iou: 0.2192 - val_accuracy: 0.6415 - val_dice_coef: 0.4538 - val_loss: 0.8027 - val_mean_iou: 0.3458
# Epoch 2/20
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 56s 176ms/step - accuracy: 0.6393 - dice_coef: 0.4540 - loss: 0.8199 - mean_iou: 0.3469 - val_accuracy: 0.7035 - val_dice_coef: 0.5628 - val_loss: 0.7039 - val_mean_iou: 0.4324
# Epoch 3/20
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 82s 255ms/step - accuracy: 0.6919 - dice_coef: 0.5672 - loss: 0.7282 - mean_iou: 0.4315 - val_accuracy: 0.7350 - val_dice_coef: 0.6307 - val_loss: 0.6461 - val_mean_iou: 0.4897
# Epoch 4/20
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 56s 176ms/step - accuracy: 0.7164 - dice_coef: 0.6146 - loss: 0.6813 - mean_iou: 0.4723 - val_accuracy: 0.7153 - val_dice_coef: 0.6255 - val_loss: 0.6861 - val_mean_iou: 0.4787
# Epoch 5/20
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 59s 184ms/step - accuracy: 0.7354 - dice_coef: 0.6429 - loss: 0.6448 - mean_iou: 0.5004 - val_accuracy: 0.7578 - val_dice_coef: 0.6684 - val_loss: 0.5943 - val_mean_iou: 0.5261
# Epoch 6/20
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 59s 185ms/step - accuracy: 0.7567 - dice_coef: 0.6684 - loss: 0.5996 - mean_iou: 0.5277 - val_accuracy: 0.7776 - val_dice_coef: 0.6810 - val_loss: 0.5611 - val_mean_iou: 0.5447
# Epoch 7/20
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 55s 172ms/step - accuracy: 0.7700 - dice_coef: 0.6829 - loss: 0.5736 - mean_iou: 0.5446 - val_accuracy: 0.7884 - val_dice_coef: 0.6929 - val_loss: 0.5239 - val_mean_iou: 0.5577
# Epoch 8/20
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 76s 239ms/step - accuracy: 0.7772 - dice_coef: 0.6943 - loss: 0.5575 - mean_iou: 0.5561 - val_accuracy: 0.8066 - val_dice_coef: 0.7124 - val_loss: 0.4849 - val_mean_iou: 0.5822
# Epoch 9/20
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 55s 172ms/step - accuracy: 0.7917 - dice_coef: 0.7114 - loss: 0.5240 - mean_iou: 0.5764 - val_accuracy: 0.8199 - val_dice_coef: 0.7418 - val_loss: 0.4576 - val_mean_iou: 0.6140
# Epoch 10/20
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 76s 237ms/step - accuracy: 0.8013 - dice_coef: 0.7217 - loss: 0.5056 - mean_iou: 0.5888 - val_accuracy: 0.8104 - val_dice_coef: 0.7295 - val_loss: 0.4747 - val_mean_iou: 0.5988
# Epoch 11/20
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 55s 171ms/step - accuracy: 0.8038 - dice_coef: 0.7251 - loss: 0.4963 - mean_iou: 0.5928 - val_accuracy: 0.8221 - val_dice_coef: 0.7315 - val_loss: 0.4540 - val_mean_iou: 0.6061
# Epoch 12/20
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.8112 - dice_coef: 0.7331 - loss: 0.4827 - mean_iou: 0.6029 - val_accuracy: 0.8225 - val_dice_coef: 0.7420 - val_loss: 0.4534 - val_mean_iou: 0.6151
# Epoch 13/20
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 56s 174ms/step - accuracy: 0.8185 - dice_coef: 0.7429 - loss: 0.4684 - mean_iou: 0.6147 - val_accuracy: 0.8284 - val_dice_coef: 0.7569 - val_loss: 0.4459 - val_mean_iou: 0.6311
# Epoch 14/20
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 76s 237ms/step - accuracy: 0.8206 - dice_coef: 0.7459 - loss: 0.4601 - mean_iou: 0.6178 - val_accuracy: 0.8239 - val_dice_coef: 0.7437 - val_loss: 0.4536 - val_mean_iou: 0.6171
# Epoch 15/20
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 82s 256ms/step - accuracy: 0.8283 - dice_coef: 0.7539 - loss: 0.4433 - mean_iou: 0.6287 - val_accuracy: 0.8354 - val_dice_coef: 0.7692 - val_loss: 0.4266 - val_mean_iou: 0.6456
# Epoch 16/20
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 55s 171ms/step - accuracy: 0.8314 - dice_coef: 0.7578 - loss: 0.4357 - mean_iou: 0.6332 - val_accuracy: 0.8487 - val_dice_coef: 0.7794 - val_loss: 0.3986 - val_mean_iou: 0.6606
# Epoch 17/20
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 55s 171ms/step - accuracy: 0.8328 - dice_coef: 0.7607 - loss: 0.4324 - mean_iou: 0.6364 - val_accuracy: 0.8412 - val_dice_coef: 0.7735 - val_loss: 0.4214 - val_mean_iou: 0.6521
# Epoch 18/20
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 55s 171ms/step - accuracy: 0.8363 - dice_coef: 0.7649 - loss: 0.4273 - mean_iou: 0.6419 - val_accuracy: 0.8566 - val_dice_coef: 0.7911 - val_loss: 0.3710 - val_mean_iou: 0.6751
# Epoch 19/20
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 76s 237ms/step - accuracy: 0.8392 - dice_coef: 0.7673 - loss: 0.4187 - mean_iou: 0.6456 - val_accuracy: 0.8441 - val_dice_coef: 0.7759 - val_loss: 0.4023 - val_mean_iou: 0.6561
# Epoch 20/20
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 82s 257ms/step - accuracy: 0.8434 - dice_coef: 0.7742 - loss: 0.4077 - mean_iou: 0.6536 - val_accuracy: 0.8294 - val_dice_coef: 0.7320 - val_loss: 0.4617 - val_mean_iou: 0.6083

# %% [markdown]
# ## 6. Evaluación del modelo
#
# 1. Se evalúa el modelo en el conjunto de prueba para obtener pérdida, exactitud y IoU medio.
#
# 2. Se calcula el coeficiente Dice y la precisión de píxel en test.

# %%
# 6.0 Cargar el mejor modelo guardado
from tensorflow.keras.models import load_model

model = load_model(
    'best_unet_model.keras',
    custom_objects={
        'MeanIoUArgmax': MeanIoUArgmax,
        'dice_coef': dice_coef
    }
)

# 6.1 Evaluación cuantitativa
results = model.evaluate(
    test_gen,
    steps=steps_test,
    return_dict=True
)
print("Pérdida (test):     ", results['loss'])
print("Exactitud (test):   ", results['accuracy'])
print("Mean IoU (test):    ", results['mean_iou'])
print("Dice Coef (test):   ", results['dice_coef'])

# 6.2 Métricas personalizadas: precisión de píxel y Dice por clase
import numpy as np

smooth = 1e-6
class_dice = np.zeros(N_CLASSES, dtype=np.float32)
pixel_matches = 0
total_pixels = 0

# Recorrer todos los lotes de test
for _ in range(steps_test):
    x_b, y_b = next(test_gen)
    y_pred = model.predict(x_b, verbose=0)
    y_pred_lbl = np.argmax(y_pred, axis=-1)
    y_true_lbl = y_b[..., 0]

    pixel_matches += np.sum(y_pred_lbl == y_true_lbl)
    total_pixels += y_true_lbl.size

    # Acumular Dice por clase
    for cls in range(N_CLASSES):
        y_t = (y_true_lbl == cls).astype(np.float32).ravel()
        y_p = (y_pred_lbl == cls).astype(np.float32).ravel()
        inter = np.sum(y_t * y_p)
        union = np.sum(y_t) + np.sum(y_p)
        class_dice[cls] += (2 * inter + smooth) / (union + smooth)

pixel_acc = pixel_matches / total_pixels
dice_scores = class_dice / steps_test

print("Precisión de píxel:    ", pixel_acc)
print("Dice por clase:        ", dice_scores)
print("Dice medio:            ", dice_scores.mean())
# Out:
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 116ms/step - accuracy: 0.8597 - dice_coef: 0.7933 - loss: 0.3695 - mean_iou: 0.6787
# Pérdida (test):      0.37843018770217896
# Exactitud (test):    0.8550869822502136
# Mean IoU (test):     0.6734115481376648
# Dice Coef (test):    0.7895729541778564
# Precisión de píxel:     0.8562259090647978
# Dice por clase:         [0.8736804 0.9008708 0.5984331]
# Dice medio:             0.7909947

# %% [markdown]
# ## 7. Predicción / Inferencia
#
# Visualizamos algunos ejemplos de test, comparando la imagen, la máscara real y la predicción, para apreciar la calidad de la segmentación.

# %%
import matplotlib.pyplot as plt
import random

# Obtener un lote del generador de test
x_batch, y_batch = next(test_gen)

# Elegir 5 índices aleatorios dentro del batch
indices = random.sample(range(BATCH_SIZE), 5)

plt.figure(figsize=(12, 12))
for i, idx in enumerate(indices):
    img = x_batch[idx]
    ygt = y_batch[idx, ..., 0]
    ypr = np.argmax(model.predict(img[np.newaxis, ...]), axis=-1)[0]

    # Imagen original
    ax = plt.subplot(5, 3, 3*i + 1)
    ax.imshow((img * 255).astype('uint8'))
    ax.set_title('Imagen')
    ax.axis('off')

    # Máscara real
    ax = plt.subplot(5, 3, 3*i + 2)
    ax.imshow(ygt, cmap='gray')
    ax.set_title('Máscara GT')
    ax.axis('off')

    # Máscara predicha
    ax = plt.subplot(5, 3, 3*i + 3)
    ax.imshow(ypr, cmap='gray')
    ax.set_title('Predicción')
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %% [markdown]
# ## 8. Conclusiones y Discusión
#
# Las siguientes preguntas constituyen el entregable de esta sección. Deben responderse directamente en este notebook, sustentando las respuestas con los resultados obtenidos y cualquier análisis relevante.
#
# 1. **Conexiones de salto (skip connections)**
#
#    - Explicar por qué concatenar mapas del encoder con los del decoder conserva información espacial detallada.
#
#   Las conexiones de salto en la arquitectura U-Net implementada facilitan la concatenación de mapas de características del encoder (alta resolución espacial, bajo nivel semántico) con los del decoder (baja resolución espacial, alto nivel semántico). Este mecanismo se implementa mediante la fusión de capas en el bloque up_block, donde se aplica Conv2DTranspose para upsampling, seguido de concatenación con mapas del encoder (ej: capa f3 del tercer nivel del encoder) y convoluciones posteriores. Este proceso permite recuperar información espacial perdida durante las operaciones de MaxPooling en el encoder, esencial para reconstruir estructuras como bordes. Sin embargo, el coeficiente Dice de 0.598 para la clase de bordes indica limitaciones, atribuibles al redimensionamiento de imágenes a 160x160 (pérdida de detalles finos), la distribución desbalanceada de píxeles en las máscaras (clase 2 como minoritaria) y la función de pérdida sparse_categorical_crossentropy, que no prioriza explícitamente regiones críticas. Para optimizar el rendimiento en contornos, se propone integrar mecanismos de atención en las conexiones de salto (ej: Attention Gates) para ponderar características espaciales relevantes durante la fusión, o implementar funciones de pérdida especializadas (ej: Boundary Loss) que incrementen el peso de los píxeles de borde durante el entrenamiento.
#
# 2. **Profundidad y número de filtros**
#
#    - Analizar el impacto de modificar la cantidad de bloques y filtros sobre la precisión y el costo computacional.
#
#   Aumentar el número de bloques filtros mejoraría la capacidad de extraer características complejas que pueden permitir alcanzar una mejor presición, pero se incrementaría el costo computacional (más parámetros y por ello mas tiempo de entrenamiento). En el código, el encoder usa 16, 32 y 64 filtros; duplicarlos podría mejorar resultados, pero requeriría ajustar el batch size para evitar sobrecarga de memoria. Por otro lado, reducir bloques: disminuiría el costo computacional, pero perdería capacidad de modelar detalles, especialmente en regiones pequeñas (como se observa en el bajo Dice para bordes).
#
# 3. **Regularización**
#
#    - Evaluar el efecto del `Dropout` y plantear otras técnicas para mejorar la generalización.
#
#   La capa Dropout (p=0.2), implementada tras cada operación de MaxPooling en el encoder, actúa mediante la desactivación aleatoria del 20% de las unidades durante el entrenamiento, reduciendo efectivamente la coadaptación entre neuronas y previniendo el sobreajuste. Como técnicas complementarias, se sugieren: (1) transformaciones de data augmentation (afines y en espacio de color) para enriquecer la diversidad del conjunto de entrenamiento; (2) regularización L2 (λ=0.001) aplicada a los kernels convolucionales, controlando la magnitud de los pesos; y (3) Batch Normalization para estabilizar la distribución de activaciones entre capas. El esquema actual, que incluye Early Stopping (patience=5, monitor='val_loss'), demuestra eficacia con el volumen de datos disponible (n=7,349). Para conjuntos más pequeños, se recomienda incrementar la tasa de Dropout (p=0.3-0.5) y priorizar técnicas de aumento de datos. En arquitecturas con mayor profundidad, la implementación de Batch Normalization resulta particularmente beneficiosa, mejorando tanto la estabilidad del gradiente como la velocidad de convergencia durante el proceso de backpropagation.
#
#
# 4. **Métricas de evaluación**
#
#    - Comparar la rigurosidad y aplicabilidad de **IoU** frente a **coeficiente Dice** en distintos escenarios.
#
#   El Intersection over Union (IoU) y el coeficiente Dice son métricas de superposición espacial utilizadas en segmentación de imágenes. El IoU calcula la proporción entre el área de intersección y la unión de las regiones predicha y verdadera, mientras que el coeficiente Dice (F1-score espacial) considera el doble del área de intersección dividido por la suma de áreas individuales. Matemáticamente, ambas están relacionadas (Dice = 2*IoU/(1+IoU)), pero presentan diferencias prácticas: el IoU es más estricto al penalizar en mayor medida las predicciones con falsos positivos/negativos, lo que lo hace preferible en aplicaciones médicas donde la precisión en bordes es crítica. El coeficiente Dice, al ser menos sensible a desbalances pequeños entre intersección y unión, suele mostrar valores numéricamente más altos y es más utilizado en escenarios donde se prioriza la recuperación de regiones completas (segmentación de órganos). En la implementación actual, el IoU medio (0.67) y Dice (0.79) reflejan esta relación matemática esperada, donde el valor de Dice supera consistentemente al IoU para un mismo nivel de desempeño. La elección entre métricas depende del contexto: IoU para evaluación conservadora en tareas de delimitación precisa, Dice para optimización directa del solapamiento en segmentación de estructuras completas.
#
# 5. **Análisis de resultados y mejoras**
#
#    - Identificar patrones de error (por ejemplo, en contornos o regiones pequeñas) y proponer extensiones de U-Net para optimización futura.
#
#   El análisis de los resultados del modelo U-Net actual revela dos problemas principales en la segmentación. En primer lugar, se observa un bajo rendimiento en la delimitación precisa de bordes, evidenciado por un coeficiente Dice de solo 0.59 para esta clase. Este problema surge principalmente por la reducción progresiva de resolución espacial durante las operaciones de pooling en el encoder, combinado con el hecho de que las conexiones de salto estándar no priorizan adecuadamente los detalles finos de los contornos. Además, la función de pérdida actual trata todas las clases por igual, sin enfatizar suficientemente la importancia de los bordes en la segmentación.
#
#   Un segundo problema identificado es la pérdida de detalle en regiones pequeñas y delgadas, como patas u orejas de mascotas. Esto se debe principalmente al redimensionamiento inicial de las imágenes a 160x160 píxeles, que hace que estructuras finas queden representadas por muy pocos píxeles. La arquitectura actual tampoco incorpora mecanismos efectivos para preservar y combinar características a múltiples escalas, lo que agrava este problema en regiones de pequeño tamaño.
#
#   Para abordar estas limitaciones, se proponen varias mejoras técnicas. La implementación de mecanismos de atención en las conexiones de salto permitiría al modelo aprender automáticamente a enfatizar características espacialmente relevantes, particularmente en regiones de borde. Estos módulos, conocidos como Attention Gates, podrían mejorar la precisión en bordes hasta en un 15-20%. Complementariamente, la adopción de funciones de pérdida especializadas, como una combinación de Boundary Loss y Focal Loss, ayudaría a manejar mejor el desbalance de clases y a enfocar el aprendizaje en los contornos.
#
#   Otra línea de mejora considera el manejo multiresolución de las características. Dos enfoques parecen prometedores: aumentar el tamaño de entrada a 256x256 píxeles (requiriendo ajustes en la capacidad del modelo) o implementar convoluciones dilatadas en las capas más profundas del encoder, lo que permitiría preservar contexto sin aumentar significativamente los parámetros. Finalmente, la incorporación de Deep Supervision mediante pérdidas auxiliares en capas intermedias del decoder podría guiar más efectivamente el aprendizaje de características a diferentes escalas, mejorando particularmente la segmentación de estructuras finas.
#
#   La estrategia de implementación recomendada sigue un enfoque incremental. Se sugiere comenzar con la adición de Attention Gates y Boundary Loss, por ser modificaciones relativamente sencillas con alto potencial de mejora. Tras evaluar su impacto en métricas específicas (como el Dice para bordes y la precisión por píxel), se podría considerar progresivamente otras mejoras como el aumento de resolución o la supervisión multinivel, siempre manteniendo un balance entre complejidad y rendimiento. Este enfoque permite abordar las limitaciones identificadas mientras se preserva la simplicidad y eficiencia computacional que hacen valiosa a la arquitectura U-Net original.
